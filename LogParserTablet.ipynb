# %%
import matplotlib.pyplot as plt

##Set PATH
path='/Users/louise/Documents/source/LogFileReader/logging_files_may19/'
fileTablet = 'loggerFile_tablet.txt'

#contains the file broken into a list 
fileListTablet=[]

f = open(path+fileTablet, 'r') #Open file in read mode
print('Displaying: ', fileTablet)
for num, line in enumerate(f):
    fileListTablet.append(line.split()) #make the list from the file
    print('Line: ', line.split())
f.close()
# Out:
# Displaying:  loggerFile_tablet.txt
# Line:  ['NewSESSION', 'Thu', 'May', '18', '08:04:10', '2017']
# Line:  ['light5', 'ON', 'Thu', 'May', '18', '08:04:10', '2017']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:15', '2017']
# Line:  ['pos:', '13', '66']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:15', '2017']
# Line:  ['pos:', '13', '66']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:15', '2017']
# Line:  ['pos:', '13', '66']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:15', '2017']
# Line:  ['pos:', '13', '66']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '13', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '14', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '14', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '14', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '14', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '15', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '15', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '17', '64']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '19', '64']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '20', '63']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '22', '63']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '24', '62']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '26', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '29', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '33', '59']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '36', '59']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '39', '58']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '44', '57']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '47', '56']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '48', '56']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '50', '55']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '53', '54']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '55', '54']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '60', '53']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '62', '52']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '64', '52']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '66', '52']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '68', '51']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '70', '51']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '72', '51']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '74', '50']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '76', '49']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '80', '48']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '81', '48']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '82', '48']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '84', '47']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '85', '47']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '87', '47']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '90', '46']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '92', '46']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '93', '45']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:16', '2017']
# Line:  ['pos:', '94', '45']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '95', '45']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '97', '44']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '99', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '101', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '102', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '103', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '103', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '104', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '104', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '104', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '105', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '106', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '106', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '106', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '107', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '107', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '107', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '107', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '107', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '107', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '107', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '108', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '108', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '108', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '108', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '108', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '108', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '108', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '108', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:17', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '110', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '110', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '110', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '110', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '110', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '110', '44']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '44']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '45']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '45']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '109', '46']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '108', '46']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '108', '47']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '107', '47']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '106', '48']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '105', '48']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '104', '48']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '103', '49']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '102', '49']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '101', '49']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '99', '49']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '99', '49']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '98', '49']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '97', '49']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:18', '2017']
# Line:  ['pos:', '96', '49']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '95', '49']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '94', '48']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '94', '48']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '93', '48']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '93', '48']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '93', '48']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '93', '47']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '92', '47']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '91', '46']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '91', '46']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '91', '45']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '90', '44']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '90', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '90', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '90', '41']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '89', '41']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '89', '39']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '88', '38']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '88', '36']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '88', '35']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '87', '33']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '87', '32']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '85', '29']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '85', '27']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '84', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '84', '25']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '84', '25']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '83', '23']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '82', '22']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '82', '21']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '81', '18']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '80', '17']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '80', '16']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '79', '15']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '78', '13']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '77', '12']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '75', '9']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '74', '8']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '73', '7']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '72', '6']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '70', '4']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '69', '4']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '66', '2']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '64', '2']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '63', '1']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '60', '1']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '58', '0']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '57', '0']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '55', '0']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:19', '2017']
# Line:  ['pos:', '53', '0']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '52', '0']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '48', '0']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '46', '1']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '44', '1']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '43', '1']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '41', '2']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '39', '2']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '34', '4']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '32', '5']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '32', '5']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '28', '7']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '26', '8']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '23', '9']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '22', '11']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '20', '12']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '18', '13']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '15', '15']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '13', '16']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '12', '17']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '12', '17']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '11', '17']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '11', '18']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '10', '18']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '9', '19']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '8', '19']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '6', '19']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '6', '19']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '5', '20']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '4', '20']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '4', '20']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '3', '21']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '2', '21']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '2', '22']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '1', '23']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '1', '24']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '24']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '25']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '25']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '27']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '27']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:20', '2017']
# Line:  ['pos:', '0', '27']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '1', '28']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '2', '29']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '3', '29']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '3', '30']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '4', '30']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '6', '31']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '7', '32']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '9', '34']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '10', '35']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '11', '37']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '13', '39']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '14', '41']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '15', '42']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '16', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '17', '45']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '17', '46']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '19', '49']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '20', '51']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '20', '52']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '21', '54']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '21', '55']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '22', '56']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '23', '58']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '23', '59']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '23', '59']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '24', '60']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '24', '60']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '24', '60']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '24', '60']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '24', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '25', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '25', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '25', '62']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '25', '62']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '26', '63']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '26', '63']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '26', '63']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '28', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '29', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '30', '66']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '32', '67']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '33', '68']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '34', '68']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '36', '69']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '37', '70']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '38', '71']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '40', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '41', '73']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '43', '74']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:21', '2017']
# Line:  ['pos:', '44', '75']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '46', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '48', '77']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '51', '78']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '52', '80']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '54', '81']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '57', '83']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '59', '84']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '60', '84']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '61', '85']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '62', '86']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '63', '87']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '66', '89']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '67', '89']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '67', '90']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '68', '90']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '69', '91']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '69', '91']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '70', '92']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '70', '92']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '70', '92']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '70', '92']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '71', '93']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '71', '93']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '71', '93']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '71', '93']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '71', '93']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '71', '94']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '71', '94']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '71', '94']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '72', '94']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '72', '94']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '72', '94']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '72', '95']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '72', '95']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '72', '95']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '72', '95']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '72', '96']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:22', '2017']
# Line:  ['pos:', '72', '96']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:23', '2017']
# Line:  ['pos:', '72', '96']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:23', '2017']
# Line:  ['pos:', '72', '96']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:24', '2017']
# Line:  ['pos:', '72', '96']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:24', '2017']
# Line:  ['pos:', '72', '96']
# Line:  ['light5', 'OFF', 'Thu', 'May', '18', '08:04:26', '2017']
# Line:  ['light3', 'ON', 'Thu', 'May', '18', '08:04:27', '2017']
# Line:  ['light5', 'ON', 'Thu', 'May', '18', '08:04:33', '2017']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '117', '27']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '117', '27']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '117', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '117', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '117', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '116', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '115', '25']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '114', '25']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '112', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '110', '26']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '108', '28']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '104', '30']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '102', '31']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '99', '33']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '96', '35']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '94', '37']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '91', '39']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '85', '43']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '82', '45']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '80', '47']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '74', '50']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '72', '51']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '69', '53']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '68', '54']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '65', '55']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '63', '56']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '59', '58']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '58', '59']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '56', '60']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '55', '60']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '53', '60']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '52', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '51', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '50', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:38', '2017']
# Line:  ['pos:', '49', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '47', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '47', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '46', '61']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '45', '62']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '44', '62']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '44', '62']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '42', '62']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '42', '63']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '41', '63']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '40', '63']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '40', '64']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '39', '64']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '37', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '37', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '36', '65']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '36', '66']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '35', '66']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '35', '66']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '35', '66']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '35', '66']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '35', '66']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '34', '67']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '34', '67']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '34', '68']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '34', '69']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '70']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '71']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '74']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '78']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '80']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '81']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '83']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '85']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '86']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '87']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:39', '2017']
# Line:  ['pos:', '33', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:40', '2017']
# Line:  ['pos:', '33', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:40', '2017']
# Line:  ['pos:', '33', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '37', '85']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '37', '85']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '37', '86']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '36', '86']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '36', '86']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '36', '86']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '35', '86']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '34', '87']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '33', '87']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '33', '87']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '32', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '32', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '32', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '32', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '32', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '32', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '31', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '31', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '31', '89']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '31', '89']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:43', '2017']
# Line:  ['pos:', '31', '89']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:46', '2017']
# Line:  ['pos:', '50', '98']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:46', '2017']
# Line:  ['pos:', '44', '97']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:46', '2017']
# Line:  ['pos:', '43', '97']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:46', '2017']
# Line:  ['pos:', '42', '96']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:46', '2017']
# Line:  ['pos:', '41', '96']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:46', '2017']
# Line:  ['pos:', '39', '96']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:46', '2017']
# Line:  ['pos:', '36', '94']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:46', '2017']
# Line:  ['pos:', '33', '94']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '27', '92']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '24', '91']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '22', '91']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '19', '90']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '16', '89']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '13', '88']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '8', '86']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '5', '86']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '4', '86']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '2', '85']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '0', '85']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-2', '84']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-6', '83']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-7', '83']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-8', '82']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-12', '82']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-14', '81']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-15', '81']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-17', '81']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-18', '80']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-18', '80']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-20', '80']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-21', '79']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-22', '79']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-23', '79']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-24', '78']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-24', '78']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-26', '78']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-26', '77']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-27', '77']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-28', '77']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-28', '77']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-29', '77']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-29', '77']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-29', '77']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-29', '77']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-29', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-30', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-30', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-30', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-30', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-30', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-30', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-30', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-31', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-31', '76']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-32', '75']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-32', '75']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-33', '75']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:47', '2017']
# Line:  ['pos:', '-33', '75']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-34', '75']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-34', '75']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-35', '75']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-35', '75']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-36', '75']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-36', '74']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-37', '74']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-37', '74']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-38', '74']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-38', '74']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-39', '74']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-40', '74']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-40', '74']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-41', '74']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-41', '73']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-42', '73']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-42', '73']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-43', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-44', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-44', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-45', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-45', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-46', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-46', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-46', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-46', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-47', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-47', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-47', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-48', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-48', '72']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-48', '71']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-49', '71']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-49', '71']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-50', '71']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-50', '71']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-50', '70']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-50', '70']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-50', '70']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-51', '70']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-51', '69']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-51', '69']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-52', '69']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-52', '69']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-52', '69']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-52', '69']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-52', '69']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-53', '69']
# Line:  ['positionChanged', 'Thu', 'May', '18', '08:04:48', '2017']
# Line:  ['pos:', '-53', '69']
# Line:  ['light1', 'ON', 'Thu', 'May', '18', '08:05:02', '2017']
# Line:  ['light6', 'ON', 'Thu', 'May', '18', '08:05:02', '2017']
# Line:  ['light2', 'ON', 'Thu', 'May', '18', '08:05:10', '2017']
# Line:  ['light3', 'OFF', 'Thu', 'May', '18', '08:05:32', '2017']
# Line:  ['light5', 'OFF', 'Thu', 'May', '18', '08:05:33', '2017']
# Line:  ['light1', 'OFF', 'Thu', 'May', '18', '08:05:33', '2017']
# Line:  ['light6', 'OFF', 'Thu', 'May', '18', '08:05:34', '2017']
# Line:  ['light2', 'OFF', 'Thu', 'May', '18', '08:05:35', '2017']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '7', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '10', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '12', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '15', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '17', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '20', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '25', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '30', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '33', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '38', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '40', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '43', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '45', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '48', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '51', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '56', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '61', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '63', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '66', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '68', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '71', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '73', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:39', '2017']
# Line:  ['intensity:', '76', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '79', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '81', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '84', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '86', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '89', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '91', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '96', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '99', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '102', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '104', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '107', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '109', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '114', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '119', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '122', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '127', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '132', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '135', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '137', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '142', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '147', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '150', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '153', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '155', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '158', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '160', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '163', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '165', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '168', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '170', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '173', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '175', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '178', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '181', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:40', '2017']
# Line:  ['intensity:', '183', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:41', '2017']
# Line:  ['intensity:', '181', '40039']
# Line:  ['intensityChanged', 'Thu', 'May', '18', '08:05:41', '2017']
# Line:  ['intensity:', '178', '40039']

# %%
# look for how many times a light was turned on / off (tablet)
Light1ON = 0
Light1OFF = 0
Light2ON = 0
Light2OFF = 0
Light3ON = 0
Light3OFF = 0
Light4ON = 0
Light4OFF = 0
Light5ON = 0
Light5OFF = 0
Light6ON = 0
Light6OFF = 0
Light7ON = 0
Light7OFF = 0

if fileTablet.find('tablet') !=-1:
    #Loop through all the lines in the file
    for num3 in range(len(fileListTablet)):
        strline = fileListTablet[num3]
        #print('num:', num2)
        if len(strline) == 0:
            # do nothing
            x = 1
        #light1
        elif 'light1' == strline[0] and 'ON' == strline[1]:
            Light1ON = Light1ON + 1
            print('1:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light1' == strline[0] and 'OFF' == strline[1]:
            Light1OFF = Light1OFF + 1
            print('1:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light2
        elif 'light2' == strline[0] and 'ON' == strline[1]:
            Light2ON = Light2ON + 1
            print('2:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light2' == strline[0] and 'OFF' == strline[1]:
            Light2OFF = Light2OFF + 1
            print('2:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light3
        elif 'light3' == strline[0] and 'ON' == strline[1]:
            Light3ON = Light3ON + 1
            print('3:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light3' == strline[0] and 'OFF' == strline[1]:
            Light3OFF = Light3OFF + 1
            print('3:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light4
        elif 'light4' == strline[0] and 'ON' == strline[1]:
            Light4ON = Light4ON + 1
            print('4:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light4' == strline[0] and 'OFF' == strline[1]:
            Light4OFF = Light4OFF + 1
            print('4:', strline[0], 'was turned OFF', strline[2], 'at', strline[5])
        
        #light5
        elif 'light5' == strline[0] and 'ON' == strline[1]:
            Light5ON = Light5ON + 1
            print('5:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light5' == strline[0] and 'OFF' == strline[1]:
            Light5OFF = Light5OFF + 1
            print('5:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light6
        elif 'light6' == strline[0] and 'ON' == strline[1]:
            Light6ON = Light6ON + 1
            print('6:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light6' == strline[0] and 'OFF' == strline[1]:
            Light6OFF = Light6OFF + 1
            print('6:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light7
        elif 'light7' == strline[0] and 'ON' == strline[1]:
            Light7ON = Light7ON + 1
            print('7:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light7' == strline[0] and 'OFF' == strline[1]:
            Light7OFF = Light7OFF + 1
            print('7:', strline[0], 'was turned OFF', strline[2], 'at', strline[5])
       
print('Light1 turned ON: ', Light1ON)
print('Light1 turned OFF: ', Light1OFF)
print('Light2 turned ON: ', Light2ON)
print('Light2 turned OFF: ', Light2OFF)
print('Light3 turned ON: ', Light3ON)
print('Light3 turned OFF: ', Light3OFF)
print('Light4 turned ON: ', Light4ON)
print('Light4 turned OFF: ', Light4OFF)
print('Light5 turned ON: ', Light5ON)
print('Light5 turned OFF: ', Light5OFF)
print('Light6 turned ON: ', Light6ON)
print('Light6 turned OFF: ', Light6OFF)
print('Light7 turned ON: ', Light7ON)
print('Light7 turned OFF: ', Light7OFF)
# Out:
# 5: light5 was turned ON  Thu at 08:04:10
# 5: light5 was turned OFF  Thu at 08:04:26
# 3: light3 was turned ON  Thu at 08:04:27
# 5: light5 was turned ON  Thu at 08:04:33
# 1: light1 was turned ON  Thu at 08:05:02
# 6: light6 was turned ON  Thu at 08:05:02
# 2: light2 was turned ON  Thu at 08:05:10
# 3: light3 was turned OFF  Thu at 08:05:32
# 5: light5 was turned OFF  Thu at 08:05:33
# 1: light1 was turned OFF  Thu at 08:05:33
# 6: light6 was turned OFF  Thu at 08:05:34
# 2: light2 was turned OFF  Thu at 08:05:35
# Light1 turned ON:  1
# Light1 turned OFF:  1
# Light2 turned ON:  1
# Light2 turned OFF:  1
# Light3 turned ON:  1
# Light3 turned OFF:  1
# Light4 turned ON:  0
# Light4 turned OFF:  0
# Light5 turned ON:  2
# Light5 turned OFF:  2
# Light6 turned ON:  1
# Light6 turned OFF:  1
# Light7 turned ON:  0
# Light7 turned OFF:  0

# %%
# look for how many times the light intensity was changed(tablet)
LightIntensity = 0
lastTime = 0
lastDay= 0

if fileTablet.find('tablet') !=-1:
    for num4, strline in enumerate(fileListTablet):
        if len(strline) == 0:
            # do nothing
            x = 1
        # ['intensityChanged', 'Fri', 'Mar', '31', '12:03:47', '2017']
        if 'intensityChanged' in strline:
            t = strline[4]
            (h, m, s) = t.split(':')
            result = int(h) * 3600 + int(m) * 60 + int(s)
            #print('time in seconds: ', result)
            if lastTime == 0:
                lastDay = strline[1]
                lastTime = result
                print('light intensity changed for first time in file: ', strline[4], ' day: ', lastDay)
            elif (result - lastTime) < 60 and (result - lastTime) > -1:
                lastDay = strline[1]
                lastTime = result
            else: # count at end of movement
                LightIntensity = LightIntensity + 1
                print('light intensity ++: ', lastTime, ' day: ', lastDay)
                lastDay = strline[3]
                lastTime = result

print('Light intensity: ', LightIntensity+1) # will not have counted last one
# Out:
# light intensity changed for first time in file:  08:05:39  day:  Thu
# Light intensity:  1

# %%
# look for how many times the lights were moved (tablet)
LightMoved = 0
lastResult = 0
lastDay = 0
lastTime = 0

listOfMovementsTabletX = []
listOfMovementsTabletY = []
listOfMovementsTabletT = []
tempListX = []
tempListY = []
tempListT = []

if fileTablet.find('tablet') !=-1:
    for num5, strline in enumerate(fileListTablet):
        if len(strline) == 0:
            # do nothing
            x = 1
        # ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
        elif 'positionChanged' in strline:
            #print('position changed: ', strline[1], ' time: ', strline[4], ' dif: ', (result-lastTime) )
            t = strline[4]
            (h, m, s) = t.split(':')
            result = int(h) * 3600 + int(m) * 60 + int(s)
            #print('time in seconds: ', result)
            if lastTime == 0:
                lastDay = strline[1]
                lastResult = result
                lastTime = strline[4]
                print('light moved for first time in file: ', lastTime)
            elif (result - lastResult) < 20 and (result - lastResult) > -1:
                lastDay = strline[1]
                lastResult = result
                lastTime = strline[4]
                #print('still in same movement')
            else: 
                listOfMovementsTabletX.append(tempListX)
                listOfMovementsTabletY.append(tempListY)
                listOfMovementsTabletT.append(tempListT)
                # clear lists
                tempListX = []
                tempListY = []
                tempListT = []
                # count at end of movement
                LightMoved = LightMoved + 1
                print('light moved ++, day: ', lastDay, ' time: ',  lastTime)
                lastDay = strline[1]
                lastResult = result
                lastTime = strline[4]
            tempListT.append(result)
        if 'pos:' in strline:
            tempListX.append(strline[1])
            tempListY.append(strline[2])

listOfMovementsTabletX.append(tempListX)
listOfMovementsTabletY.append(tempListY)
listOfMovementsTabletT.append(tempListT)

print('light moved ++, day: ', lastDay, ' time: ',  lastTime)
print('Lights moved: ', LightMoved+1) # will not have counted last one
print('Length of movement list X: ', len(listOfMovementsTabletX))
print('Length of movement list T: ', len(listOfMovementsTabletT))
# Out:
# light moved for first time in file:  08:04:15
# light moved ++, day:  Thu  time:  08:04:48
# Lights moved:  1
# Length of movement list X:  1
# Length of movement list T:  1

# %%
print('Length of movement list X: ', len(listOfMovementsTabletX))
print('Length of movement list T: ', len(listOfMovementsTabletT))

if fileTablet.find('tablet') !=-1:
    for i, movementX in enumerate(listOfMovementsTabletX):
        print('i: ', i)
        print('Length X: ', len(listOfMovementsTabletX[i]))
        print('Length Y: ', len(listOfMovementsTabletY[i]))
        print('Length T: ', len(listOfMovementsTabletT[i]))
        plt.scatter(listOfMovementsTabletX[i], listOfMovementsTabletY[i], c=listOfMovementsTabletT[i], s=50, cmap='winter')
        axes = plt.gca()
        axes.set_xlim([250,-100])
        axes.set_ylim([-50,200])
        plt.show()
# Out:
# Length of movement list X:  1
# Length of movement list T:  1
# i:  0
# Length X:  516
# Length Y:  516
# Length T:  516
