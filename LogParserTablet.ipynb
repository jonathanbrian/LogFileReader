# %%
import matplotlib.pyplot as plt

##Set PATH
path='/Users/louise/Documents/source/LogFileReader/logging_files_may06/'
fileTablet = 'loggerFile_tablet.txt'

#contains the file broken into a list 
fileListTablet=[]

f = open(path+fileTablet, 'r') #Open file in read mode
print('Displaying: ', fileTablet)
for num, line in enumerate(f):
    fileListTablet.append(line.split()) #make the list from the file
    print('Line: ', line.split())
f.close()
# Out:
# Displaying:  loggerFile_tablet.txt
# Line:  ['NewSESSION', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '5', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '7', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '10', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '12', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '15', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '17', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '20', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '22', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '25', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '28', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '30', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '33', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '35', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '38', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '40', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '43', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '45', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:57', '2017']
# Line:  ['intensity:', '48', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '51', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '53', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '56', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '58', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '63', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '66', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '68', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '71', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '73', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '76', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '79', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '81', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '84', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '86', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '89', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '91', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '94', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '96', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '99', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '102', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '104', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '107', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '109', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '112', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '114', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '117', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '119', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '122', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '124', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '127', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '130', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '132', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '135', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '137', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '140', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '142', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '145', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '147', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '150', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '153', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '155', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '158', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:58', '2017']
# Line:  ['intensity:', '160', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:59', '2017']
# Line:  ['intensity:', '163', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:59', '2017']
# Line:  ['intensity:', '165', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:59', '2017']
# Line:  ['intensity:', '168', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:59', '2017']
# Line:  ['intensity:', '170', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:32:59', '2017']
# Line:  ['intensity:', '173', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:33:00', '2017']
# Line:  ['intensity:', '175', '59788']
# Line:  ['intensityChanged', 'Fri', 'Apr', '28', '13:33:00', '2017']
# Line:  ['intensity:', '178', '59788']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '40', '74']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '38', '80']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '38', '82']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '38', '82']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '39', '83']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '39', '85']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '40', '85']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '41', '87']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '44', '91']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '46', '92']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '47', '92']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '50', '93']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '51', '94']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '54', '94']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '58', '94']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '61', '93']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '62', '92']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '65', '91']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '66', '90']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '68', '89']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '71', '86']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '71', '85']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '72', '85']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '72', '84']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '73', '83']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '73', '83']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:02', '2017']
# Line:  ['pos:', '73', '82']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:03', '2017']
# Line:  ['pos:', '73', '82']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:03', '2017']
# Line:  ['pos:', '74', '82']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:03', '2017']
# Line:  ['pos:', '74', '82']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:03', '2017']
# Line:  ['pos:', '74', '83']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:03', '2017']
# Line:  ['pos:', '74', '83']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:03', '2017']
# Line:  ['pos:', '74', '83']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:03', '2017']
# Line:  ['pos:', '74', '83']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:03', '2017']
# Line:  ['pos:', '74', '83']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:03', '2017']
# Line:  ['pos:', '74', '83']
# Line:  ['positionChanged', 'Fri', 'Apr', '28', '13:33:03', '2017']
# Line:  ['pos:', '74', '83']
# Line:  ['light3', 'ON', 'Fri', 'Apr', '28', '13:33:04', '2017']
# Line:  ['light5', 'ON', 'Fri', 'Apr', '28', '13:33:05', '2017']
# Line:  ['light4', 'ON', 'Fri', 'Apr', '28', '13:33:05', '2017']
# Line:  ['light7', 'ON', 'Fri', 'Apr', '28', '13:33:05', '2017']
# Line:  ['light6', 'ON', 'Fri', 'Apr', '28', '13:33:06', '2017']
# Line:  ['light1', 'ON', 'Fri', 'Apr', '28', '13:33:06', '2017']
# Line:  ['light2', 'ON', 'Fri', 'Apr', '28', '13:33:07', '2017']
# Line:  ['light3', 'OFF', 'Fri', 'Apr', '28', '13:33:07', '2017']
# Line:  ['light5', 'OFF', 'Fri', 'Apr', '28', '13:33:07', '2017']
# Line:  ['light1', 'OFF', 'Fri', 'Apr', '28', '13:33:08', '2017']
# Line:  ['light6', 'OFF', 'Fri', 'Apr', '28', '13:33:08', '2017']
# Line:  ['light4', 'OFF', 'Fri', 'Apr', '28', '13:33:09', '2017']
# Line:  ['light7', 'OFF', 'Fri', 'Apr', '28', '13:33:09', '2017']
# Line:  ['light2', 'OFF', 'Fri', 'Apr', '28', '13:33:10', '2017']
# Line:  ['positionChanged', 'Tue', 'May', '2', '07:45:02', '2017']
# Line:  ['pos:', '-13', '61']
# Line:  ['positionChanged', 'Tue', 'May', '2', '07:45:02', '2017']
# Line:  ['pos:', '-13', '61']
# Line:  ['positionChanged', 'Tue', 'May', '2', '07:45:02', '2017']
# Line:  ['pos:', '-13', '61']
# Line:  ['positionChanged', 'Tue', 'May', '2', '07:45:02', '2017']
# Line:  ['pos:', '-13', '61']
# Line:  ['light5', 'ON', 'Tue', 'May', '2', '09:29:16', '2017']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '44', '61']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '43', '62']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '43', '62']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '43', '62']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '43', '62']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '43', '62']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '43', '63']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '43', '63']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '43', '64']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '44', '64']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '44', '65']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '45', '66']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '45', '67']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '46', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '47', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '47', '69']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '48', '70']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '49', '71']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '50', '72']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '50', '72']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '51', '73']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '51', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '52', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '53', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '54', '76']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '54', '77']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '55', '78']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '56', '78']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '56', '79']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '57', '80']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '58', '80']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '58', '80']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '59', '81']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '59', '82']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '60', '82']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '60', '83']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '60', '83']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:20', '2017']
# Line:  ['pos:', '60', '84']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '61', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '61', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '61', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '62', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '62', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '62', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '63', '87']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '63', '87']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '63', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '63', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '63', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '64', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '64', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '64', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '64', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '64', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '64', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '63', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '63', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '63', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '63', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '62', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '62', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '61', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '60', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '59', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '59', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '57', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '56', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '55', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '54', '87']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '54', '87']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '53', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '52', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '52', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '51', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '50', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '49', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '49', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '48', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '48', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '47', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '45', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '45', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '44', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '44', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '43', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:21', '2017']
# Line:  ['pos:', '43', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '41', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '41', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '40', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '39', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '38', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '38', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '37', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '37', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '36', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '35', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '34', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '34', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '33', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '33', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '32', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '32', '87']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '31', '87']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '31', '87']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '30', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '29', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '28', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '27', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '27', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '26', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '25', '90']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '24', '90']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '24', '90']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '23', '90']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '23', '91']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '22', '91']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '22', '92']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '21', '92']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '21', '92']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '20', '93']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '20', '93']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '20', '93']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '20', '93']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '19', '93']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '19', '93']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '18', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '18', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '17', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '17', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '17', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '16', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '16', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '15', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '15', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '14', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:22', '2017']
# Line:  ['pos:', '14', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '14', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '13', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '13', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '13', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '12', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '12', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '11', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '11', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '11', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '10', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '10', '93']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '9', '93']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '8', '93']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '8', '92']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '7', '92']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '6', '92']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '6', '91']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '5', '91']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '5', '91']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '4', '90']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '4', '90']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '3', '90']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '3', '90']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '2', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '2', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '1', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '1', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '1', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '0', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '0', '87']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '0', '87']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '0', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '0', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '0', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-1', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-1', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-2', '84']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-2', '84']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-2', '83']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-3', '83']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-3', '82']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-3', '82']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-4', '81']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-4', '80']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-5', '79']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-5', '79']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-6', '78']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-6', '77']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-7', '77']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:23', '2017']
# Line:  ['pos:', '-7', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '-8', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '-8', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '-8', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '-8', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '40', '95']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '39', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '39', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '38', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '38', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '38', '94']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '37', '93']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '36', '92']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '35', '92']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '34', '91']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '33', '90']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '32', '90']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '32', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '32', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '31', '89']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '30', '88']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '30', '87']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '29', '87']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '29', '86']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '27', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '27', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '27', '85']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '26', '84']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '26', '84']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '25', '84']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:24', '2017']
# Line:  ['pos:', '24', '83']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '24', '82']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '23', '82']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '22', '81']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '22', '81']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '21', '80']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '20', '80']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '19', '79']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '19', '79']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '17', '78']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '17', '78']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '16', '77']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '15', '77']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '15', '77']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '14', '76']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '12', '76']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '12', '76']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '11', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '11', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '10', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '9', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '8', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '8', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '7', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '7', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '6', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '6', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '6', '75']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '6', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '5', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '5', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '5', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '4', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '4', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '4', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '3', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '3', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '2', '74']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '2', '73']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '1', '73']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '1', '73']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '0', '72']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '0', '72']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '0', '72']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '0', '71']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '-1', '70']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '-1', '70']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '-2', '69']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '-2', '69']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '-2', '69']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:25', '2017']
# Line:  ['pos:', '-2', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:26', '2017']
# Line:  ['pos:', '-3', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:26', '2017']
# Line:  ['pos:', '-3', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:26', '2017']
# Line:  ['pos:', '-3', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:26', '2017']
# Line:  ['pos:', '-3', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:26', '2017']
# Line:  ['pos:', '-3', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:26', '2017']
# Line:  ['pos:', '-3', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:26', '2017']
# Line:  ['pos:', '-3', '67']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:26', '2017']
# Line:  ['pos:', '-3', '67']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:26', '2017']
# Line:  ['pos:', '-3', '67']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:26', '2017']
# Line:  ['pos:', '-3', '67']
# Line:  ['positionChanged', 'Tue', 'May', '2', '09:29:26', '2017']
# Line:  ['pos:', '-3', '67']
# Line:  ['light5', 'OFF', 'Tue', 'May', '2', '09:29:30', '2017']
# Line:  ['light5', 'ON', 'Tue', 'May', '2', '10:25:45', '2017']
# Line:  ['light3', 'ON', 'Tue', 'May', '2', '10:25:48', '2017']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-2', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-2', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-2', '68']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-2', '67']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-2', '67']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-2', '66']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-3', '65']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-4', '64']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-4', '63']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-5', '63']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-7', '61']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-8', '60']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:51', '2017']
# Line:  ['pos:', '-8', '60']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-9', '59']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-10', '58']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-10', '58']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-12', '56']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-13', '56']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-13', '56']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-14', '55']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-15', '55']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-15', '55']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-16', '54']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-17', '54']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-18', '53']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-18', '52']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-19', '52']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-19', '52']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-20', '51']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-20', '51']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-21', '51']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-21', '50']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-22', '49']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-22', '49']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-23', '49']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-23', '48']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-24', '48']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-24', '47']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-25', '47']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-25', '47']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-26', '46']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-26', '46']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-26', '46']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-26', '46']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-27', '46']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-27', '45']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-27', '45']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-28', '45']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-28', '44']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-28', '44']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-29', '44']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-29', '44']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-29', '43']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-29', '43']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-29', '43']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-29', '43']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-29', '43']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-29', '43']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-30', '43']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-30', '43']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-30', '43']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-30', '42']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:52', '2017']
# Line:  ['pos:', '-30', '42']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-30', '42']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-30', '42']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-30', '42']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-31', '42']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-31', '42']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-31', '41']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-31', '41']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-31', '41']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-31', '41']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-32', '41']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-32', '41']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-32', '40']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-32', '40']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-32', '40']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-32', '40']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-33', '39']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-33', '39']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-33', '39']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-34', '39']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-34', '39']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-34', '38']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-35', '38']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-35', '38']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-36', '38']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-36', '37']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-36', '37']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-36', '37']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-37', '37']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-37', '37']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-37', '36']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-38', '36']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-38', '36']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-39', '36']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-39', '35']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-39', '35']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-39', '35']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-39', '35']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-39', '35']
# Line:  ['positionChanged', 'Tue', 'May', '2', '10:25:53', '2017']
# Line:  ['pos:', '-40', '35']
# ...
# Line:  ['pos:', '6', '81']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '5', '81']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '5', '80']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '5', '79']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '4', '79']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '4', '78']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '3', '77']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '3', '77']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '2', '76']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '2', '75']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '1', '75']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '0', '74']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '0', '73']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '0', '73']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-1', '72']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-1', '72']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-2', '72']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-3', '71']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-4', '70']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-5', '70']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-6', '69']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-6', '69']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-7', '69']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-7', '69']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-8', '68']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-8', '68']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-9', '68']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-10', '67']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-10', '67']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-11', '67']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-11', '66']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-12', '66']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-12', '66']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-13', '66']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-13', '66']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-13', '65']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-14', '65']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-14', '65']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-15', '65']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-15', '65']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-15', '65']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-16', '65']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:31', '2017']
# Line:  ['pos:', '-16', '64']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-16', '64']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-17', '64']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-17', '64']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-17', '64']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-17', '64']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-18', '64']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-18', '63']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-18', '63']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-18', '63']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-19', '63']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-19', '63']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-19', '63']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-19', '63']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-19', '63']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-20', '63']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-20', '62']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-20', '62']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-20', '62']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-20', '62']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-21', '62']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-21', '62']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-21', '61']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-21', '61']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-21', '61']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-21', '61']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-21', '61']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-22', '61']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-22', '61']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-22', '61']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-22', '61']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-23', '60']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-23', '60']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-23', '60']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-24', '60']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-24', '60']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-24', '60']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-24', '60']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-25', '60']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-25', '59']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-25', '59']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-25', '59']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-26', '59']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-26', '59']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-26', '59']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-26', '59']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-27', '59']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-27', '59']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-27', '58']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-28', '58']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:32', '2017']
# Line:  ['pos:', '-28', '58']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '57']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '57']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '57']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '57']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '56']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '56']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '56']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '56']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '56']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '56']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '56']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '55']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '55']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '55']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '55']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '55']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '55']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '55']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '54']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '54']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '54']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '54']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '54']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '53']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '53']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-30', '52']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '52']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '51']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '51']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '50']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-29', '50']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-28', '50']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-28', '49']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-28', '49']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-27', '49']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-27', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-26', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:33', '2017']
# Line:  ['pos:', '-26', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-26', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-25', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-25', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-24', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-23', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-22', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-21', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-21', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-21', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-20', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-20', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-19', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-19', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-18', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-18', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-17', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-17', '47']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-16', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-16', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-15', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-15', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-15', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-14', '48']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-14', '49']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-13', '49']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-13', '49']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-12', '50']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-12', '50']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-11', '51']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-11', '51']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-11', '52']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-11', '52']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-10', '52']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-10', '52']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-10', '52']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:34', '2017']
# Line:  ['pos:', '-10', '52']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:35', '2017']
# Line:  ['pos:', '-10', '52']
# Line:  ['positionChanged', 'Thu', 'May', '4', '15:26:35', '2017']
# Line:  ['pos:', '-10', '52']

# %%
# look for how many times a light was turned on / off (tablet)
Light1ON = 0
Light1OFF = 0
Light2ON = 0
Light2OFF = 0
Light3ON = 0
Light3OFF = 0
Light4ON = 0
Light4OFF = 0
Light5ON = 0
Light5OFF = 0
Light6ON = 0
Light6OFF = 0
Light7ON = 0
Light7OFF = 0

if fileTablet.find('tablet') !=-1:
    #Loop through all the lines in the file
    for num3 in range(len(fileListTablet)):
        strline = fileListTablet[num3]
        #print('num:', num2)
        if len(strline) == 0:
            # do nothing
            x = 1
        #light1
        elif 'light1' == strline[0] and 'ON' == strline[1]:
            Light1ON = Light1ON + 1
            print('1:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light1' == strline[0] and 'OFF' == strline[1]:
            Light1OFF = Light1OFF + 1
            print('1:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light2
        elif 'light2' == strline[0] and 'ON' == strline[1]:
            Light2ON = Light2ON + 1
            print('2:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light2' == strline[0] and 'OFF' == strline[1]:
            Light2OFF = Light2OFF + 1
            print('2:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light3
        elif 'light3' == strline[0] and 'ON' == strline[1]:
            Light3ON = Light3ON + 1
            print('3:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light3' == strline[0] and 'OFF' == strline[1]:
            Light3OFF = Light3OFF + 1
            print('3:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light4
        elif 'light4' == strline[0] and 'ON' == strline[1]:
            Light4ON = Light4ON + 1
            print('4:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light4' == strline[0] and 'OFF' == strline[1]:
            Light4OFF = Light4OFF + 1
            print('4:', strline[0], 'was turned OFF', strline[2], 'at', strline[5])
        
        #light5
        elif 'light5' == strline[0] and 'ON' == strline[1]:
            Light5ON = Light5ON + 1
            print('5:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light5' == strline[0] and 'OFF' == strline[1]:
            Light5OFF = Light5OFF + 1
            print('5:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light6
        elif 'light6' == strline[0] and 'ON' == strline[1]:
            Light6ON = Light6ON + 1
            print('6:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light6' == strline[0] and 'OFF' == strline[1]:
            Light6OFF = Light6OFF + 1
            print('6:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light7
        elif 'light7' == strline[0] and 'ON' == strline[1]:
            Light7ON = Light7ON + 1
            print('7:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light7' == strline[0] and 'OFF' == strline[1]:
            Light7OFF = Light7OFF + 1
            print('7:', strline[0], 'was turned OFF', strline[2], 'at', strline[5])
       
print('Light1 turned ON: ', Light1ON)
print('Light1 turned OFF: ', Light1OFF)
print('Light2 turned ON: ', Light2ON)
print('Light2 turned OFF: ', Light2OFF)
print('Light3 turned ON: ', Light3ON)
print('Light3 turned OFF: ', Light3OFF)
print('Light4 turned ON: ', Light4ON)
print('Light4 turned OFF: ', Light4OFF)
print('Light5 turned ON: ', Light5ON)
print('Light5 turned OFF: ', Light5OFF)
print('Light6 turned ON: ', Light6ON)
print('Light6 turned OFF: ', Light6OFF)
print('Light7 turned ON: ', Light7ON)
print('Light7 turned OFF: ', Light7OFF)
# Out:
# 3: light3 was turned ON  Fri at 13:33:04
# 5: light5 was turned ON  Fri at 13:33:05
# 4: light4 was turned ON  Fri at 13:33:05
# 7: light7 was turned ON  Fri at 13:33:05
# 6: light6 was turned ON  Fri at 13:33:06
# 1: light1 was turned ON  Fri at 13:33:06
# 2: light2 was turned ON  Fri at 13:33:07
# 3: light3 was turned OFF  Fri at 13:33:07
# 5: light5 was turned OFF  Fri at 13:33:07
# 1: light1 was turned OFF  Fri at 13:33:08
# 6: light6 was turned OFF  Fri at 13:33:08
# 4: light4 was turned OFF Fri at 13:33:09
# 7: light7 was turned OFF Fri at 13:33:09
# 2: light2 was turned OFF  Fri at 13:33:10
# 5: light5 was turned ON  Tue at 09:29:16
# 5: light5 was turned OFF  Tue at 09:29:30
# 5: light5 was turned ON  Tue at 10:25:45
# 3: light3 was turned ON  Tue at 10:25:48
# 5: light5 was turned ON  Thu at 10:47:31
# 5: light5 was turned OFF  Thu at 10:47:31
# 3: light3 was turned ON  Thu at 10:47:32
# 4: light4 was turned ON  Thu at 10:47:32
# 4: light4 was turned OFF Thu at 10:47:33
# 3: light3 was turned OFF  Thu at 10:47:33
# 7: light7 was turned ON  Thu at 10:47:33
# 7: light7 was turned OFF Thu at 10:47:34
# 6: light6 was turned ON  Thu at 10:47:35
# 6: light6 was turned OFF  Thu at 10:47:35
# 1: light1 was turned ON  Thu at 10:47:36
# 1: light1 was turned OFF  Thu at 10:47:36
# 2: light2 was turned ON  Thu at 10:47:37
# 2: light2 was turned OFF  Thu at 10:47:37
# 5: light5 was turned ON  Thu at 12:14:30
# 3: light3 was turned ON  Thu at 12:14:31
# 3: light3 was turned OFF  Thu at 12:14:32
# 5: light5 was turned OFF  Thu at 12:14:33
# 5: light5 was turned ON  Thu at 12:14:34
# 5: light5 was turned OFF  Thu at 12:14:41
# 5: light5 was turned ON  Thu at 12:15:37
# 2: light2 was turned ON  Thu at 12:15:40
# 2: light2 was turned OFF  Thu at 12:15:41
# 5: light5 was turned OFF  Thu at 12:15:42
# 3: light3 was turned ON  Thu at 12:15:43
# 3: light3 was turned OFF  Thu at 12:15:45
# 5: light5 was turned ON  Thu at 12:15:53
# 5: light5 was turned OFF  Thu at 12:16:08
# 3: light3 was turned ON  Thu at 12:16:09
# 5: light5 was turned ON  Thu at 12:16:09
# 6: light6 was turned ON  Thu at 12:16:10
# 1: light1 was turned ON  Thu at 12:16:10
# 7: light7 was turned ON  Thu at 12:16:11
# 4: light4 was turned ON  Thu at 12:16:11
# 2: light2 was turned ON  Thu at 12:16:11
# 3: light3 was turned OFF  Thu at 12:16:31
# 5: light5 was turned OFF  Thu at 12:16:31
# 2: light2 was turned OFF  Thu at 12:16:32
# 4: light4 was turned OFF Thu at 12:16:33
# 7: light7 was turned OFF Thu at 12:16:33
# 6: light6 was turned OFF  Thu at 12:16:35
# 1: light1 was turned OFF  Thu at 12:16:36
# 5: light5 was turned ON  Thu at 15:25:38
# 2: light2 was turned ON  Thu at 15:26:11
# 3: light3 was turned ON  Thu at 15:26:13
# 3: light3 was turned OFF  Thu at 15:26:18
# 7: light7 was turned ON  Thu at 15:26:21
# Light1 turned ON:  3
# Light1 turned OFF:  3
# Light2 turned ON:  5
# Light2 turned OFF:  4
# Light3 turned ON:  7
# Light3 turned OFF:  6
# Light4 turned ON:  3
# Light4 turned OFF:  3
# Light5 turned ON:  10
# Light5 turned OFF:  8
# Light6 turned ON:  3
# Light6 turned OFF:  3
# Light7 turned ON:  4
# Light7 turned OFF:  3

# %%
# look for how many times the light intensity was changed(tablet)
LightIntensity = 0
lastTime = 0
lastDay= 0

if fileTablet.find('tablet') !=-1:
    for num4, strline in enumerate(fileListTablet):
        if len(strline) == 0:
            # do nothing
            x = 1
        # ['intensityChanged', 'Fri', 'Mar', '31', '12:03:47', '2017']
        if 'intensityChanged' in strline:
            t = strline[4]
            (h, m, s) = t.split(':')
            result = int(h) * 3600 + int(m) * 60 + int(s)
            #print('time in seconds: ', result)
            if lastTime == 0:
                lastDay = strline[1]
                lastTime = result
                print('light intensity changed for first time in file: ', strline[4], ' day: ', lastDay)
            elif (result - lastTime) < 60 and (result - lastTime) > -1:
                lastDay = strline[1]
                lastTime = result
            else: # count at end of movement
                LightIntensity = LightIntensity + 1
                print('light intensity ++: ', lastTime, ' day: ', lastDay)
                lastDay = strline[3]
                lastTime = result

print('Light intensity: ', LightIntensity+1) # will not have counted last one
# Out:
# light intensity changed for first time in file:  13:32:57  day:  Fri
# light intensity ++:  48780  day:  Fri
# Light intensity:  2

# %%
# look for how many times the lights were moved (tablet)
LightMoved = 0
lastResult = 0
lastDay = 0
lastTime = 0

listOfMovementsTabletX = []
listOfMovementsTabletY = []
listOfMovementsTabletT = []
tempListX = []
tempListY = []
tempListT = []

if fileTablet.find('tablet') !=-1:
    for num5, strline in enumerate(fileListTablet):
        if len(strline) == 0:
            # do nothing
            x = 1
        # ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
        elif 'positionChanged' in strline:
            #print('position changed: ', strline[1], ' time: ', strline[4], ' dif: ', (result-lastTime) )
            t = strline[4]
            (h, m, s) = t.split(':')
            result = int(h) * 3600 + int(m) * 60 + int(s)
            #print('time in seconds: ', result)
            if lastTime == 0:
                lastDay = strline[1]
                lastResult = result
                lastTime = strline[4]
                print('light moved for first time in file: ', lastTime)
            elif (result - lastResult) < 20 and (result - lastResult) > -1:
                lastDay = strline[1]
                lastResult = result
                lastTime = strline[4]
                #print('still in same movement')
            else: 
                listOfMovementsTabletX.append(tempListX)
                listOfMovementsTabletY.append(tempListY)
                listOfMovementsTabletT.append(tempListT)
                # clear lists
                tempListX = []
                tempListY = []
                tempListT = []
                # count at end of movement
                LightMoved = LightMoved + 1
                print('light moved ++, day: ', lastDay, ' time: ',  lastTime)
                lastDay = strline[1]
                lastResult = result
                lastTime = strline[4]
            tempListT.append(result)
        if 'pos:' in strline:
            tempListX.append(strline[1])
            tempListY.append(strline[2])

listOfMovementsTabletX.append(tempListX)
listOfMovementsTabletY.append(tempListY)
listOfMovementsTabletT.append(tempListT)

print('light moved ++, day: ', lastDay, ' time: ',  lastTime)
print('Lights moved: ', LightMoved+1) # will not have counted last one
print('Length of movement list X: ', len(listOfMovementsTabletX))
print('Length of movement list T: ', len(listOfMovementsTabletT))
# Out:
# light moved for first time in file:  13:33:02
# light moved ++, day:  Fri  time:  13:33:03
# light moved ++, day:  Tue  time:  07:45:02
# light moved ++, day:  Tue  time:  09:29:26
# light moved ++, day:  Tue  time:  10:25:59
# light moved ++, day:  Tue  time:  10:32:17
# light moved ++, day:  Tue  time:  10:44:38
# light moved ++, day:  Tue  time:  12:20:22
# light moved ++, day:  Tue  time:  14:40:34
# light moved ++, day:  Tue  time:  15:20:44
# light moved ++, day:  Thu  time:  12:14:40
# light moved ++, day:  Thu  time:  12:16:25
# light moved ++, day:  Thu  time:  15:26:07
# light moved ++, day:  Thu  time:  15:26:35
# Lights moved:  13
# Length of movement list X:  13
# Length of movement list T:  13

# %%
print('Length of movement list X: ', len(listOfMovementsTabletX))
print('Length of movement list T: ', len(listOfMovementsTabletT))

if fileTablet.find('tablet') !=-1:
    for i, movementX in enumerate(listOfMovementsTabletX):
        print('i: ', i)
        print('Length X: ', len(listOfMovementsTabletX[i]))
        print('Length Y: ', len(listOfMovementsTabletY[i]))
        print('Length T: ', len(listOfMovementsTabletT[i]))
        plt.scatter(listOfMovementsTabletX[i], listOfMovementsTabletY[i], c=listOfMovementsTabletT[i], s=50, cmap='winter')
        axes = plt.gca()
        axes.set_xlim([250,-100])
        axes.set_ylim([-50,200])
        plt.show()
# Out:
# Length of movement list X:  13
# Length of movement list T:  13
# i:  0
# Length X:  37
# Length Y:  37
# Length T:  37
# i:  1
# Length X:  4
# Length Y:  4
# Length T:  4
# i:  2
# Length X:  277
# Length Y:  277
# Length T:  277
# i:  3
# Length X:  220
# Length Y:  220
# Length T:  220
# i:  4
# Length X:  182
# Length Y:  182
# Length T:  182
# i:  5
# Length X:  479
# Length Y:  479
# Length T:  479
# i:  6
# Length X:  234
# Length Y:  234
# Length T:  234
# i:  7
# Length X:  230
# Length Y:  230
# Length T:  230
# i:  8
# Length X:  383
# Length Y:  383
# Length T:  383
# i:  9
# Length X:  79
# Length Y:  79
# Length T:  79
# i:  10
# Length X:  426
# Length Y:  426
# Length T:  426
# i:  11
# Length X:  1078
# Length Y:  1078
# Length T:  1078
# i:  12
# Length X:  226
# Length Y:  226
# Length T:  226
