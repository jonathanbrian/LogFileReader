# %%
import matplotlib.pyplot as plt

##Set PATH
path='/Users/louise/Documents/source/LogFileReader/logging_files_april19/'
fileTablet = 'loggerFile_tablet.txt'

#contains the file broken into a list 
fileListTablet=[]

f = open(path+fileTablet, 'r') #Open file in read mode
print('Displaying: ', fileTablet)
for num, line in enumerate(f):
    fileListTablet.append(line.split()) #make the list from the file
    print('Line: ', line.split())
f.close()
# Out:
# Displaying:  loggerFile_tablet.txt
# Line:  ['NewSESSION', 'Fri', 'Mar', '31', '12:03:40', '2017']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
# Line:  ['pos:', '-8', '106']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
# Line:  ['pos:', '5', '99']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
# Line:  ['pos:', '40', '89']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
# Line:  ['pos:', '42', '88']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
# Line:  ['pos:', '81', '63']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
# Line:  ['pos:', '85', '47']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
# Line:  ['pos:', '84', '47']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
# Line:  ['pos:', '52', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
# Line:  ['pos:', '22', '78']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
# Line:  ['pos:', '9', '89']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:41', '2017']
# Line:  ['pos:', '23', '85']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:41', '2017']
# Line:  ['pos:', '45', '73']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:41', '2017']
# Line:  ['pos:', '38', '69']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:41', '2017']
# Line:  ['pos:', '35', '68']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:41', '2017']
# Line:  ['pos:', '36', '68']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:03:41', '2017']
# Line:  ['pos:', '36', '68']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:45', '2017']
# Line:  ['intensity:', '10', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:45', '2017']
# Line:  ['intensity:', '35', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:45', '2017']
# Line:  ['intensity:', '51', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:45', '2017']
# Line:  ['intensity:', '68', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:45', '2017']
# Line:  ['intensity:', '79', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:46', '2017']
# Line:  ['intensity:', '107', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:46', '2017']
# Line:  ['intensity:', '127', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:46', '2017']
# Line:  ['intensity:', '142', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:46', '2017']
# Line:  ['intensity:', '150', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:46', '2017']
# Line:  ['intensity:', '155', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:46', '2017']
# Line:  ['intensity:', '160', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:46', '2017']
# Line:  ['intensity:', '163', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:47', '2017']
# Line:  ['intensity:', '165', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:47', '2017']
# Line:  ['intensity:', '170', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:47', '2017']
# Line:  ['intensity:', '173', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:47', '2017']
# Line:  ['intensity:', '175', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:47', '2017']
# Line:  ['intensity:', '178', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:47', '2017']
# Line:  ['intensity:', '181', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:47', '2017']
# Line:  ['intensity:', '183', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:49', '2017']
# Line:  ['intensity:', '181', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:49', '2017']
# Line:  ['intensity:', '178', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:49', '2017']
# Line:  ['intensity:', '175', '48692']
# Line:  ['intensityChanged', 'Fri', 'Mar', '31', '12:03:51', '2017']
# Line:  ['intensity:', '178', '48692']
# Line:  ['light5', 'ON', 'Fri', 'Mar', '31', '12:03:53', '2017']
# Line:  ['light3', 'ON', 'Fri', 'Mar', '31', '12:03:55', '2017']
# Line:  ['light3', 'OFF', 'Fri', 'Mar', '31', '12:03:56', '2017']
# Line:  ['light4', 'ON', 'Fri', 'Mar', '31', '12:03:56', '2017']
# Line:  ['light7', 'ON', 'Fri', 'Mar', '31', '12:03:57', '2017']
# Line:  ['light6', 'ON', 'Fri', 'Mar', '31', '12:03:57', '2017']
# Line:  ['light1', 'ON', 'Fri', 'Mar', '31', '12:03:58', '2017']
# Line:  ['light2', 'ON', 'Fri', 'Mar', '31', '12:03:58', '2017']
# Line:  ['light3', 'ON', 'Fri', 'Mar', '31', '12:03:59', '2017']
# Line:  ['light5', 'OFF', 'Fri', 'Mar', '31', '12:03:59', '2017']
# Line:  ['light2', 'OFF', 'Fri', 'Mar', '31', '12:04:00', '2017']
# Line:  ['light3', 'OFF', 'Fri', 'Mar', '31', '12:04:00', '2017']
# Line:  ['light4', 'OFF', 'Fri', 'Mar', '31', '12:04:01', '2017']
# Line:  ['light7', 'OFF', 'Fri', 'Mar', '31', '12:04:01', '2017']
# Line:  ['light6', 'OFF', 'Fri', 'Mar', '31', '12:04:01', '2017']
# Line:  ['light1', 'OFF', 'Fri', 'Mar', '31', '12:04:04', '2017']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:04:11', '2017']
# Line:  ['pos:', '27', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:04:11', '2017']
# Line:  ['pos:', '41', '77']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:04:11', '2017']
# Line:  ['pos:', '41', '77']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:04:11', '2017']
# Line:  ['pos:', '46', '72']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:04:11', '2017']
# Line:  ['pos:', '46', '71']
# Line:  ['light5', 'ON', 'Fri', 'Mar', '31', '12:06:32', '2017']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '58', '79']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '72', '69']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '73', '66']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '75', '63']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '76', '61']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '77', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '77', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '77', '52']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '76', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '75', '49']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '73', '49']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '63', '52']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '58', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '53', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '48', '61']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '42', '64']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '37', '67']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '26', '73']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '21', '75']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '17', '78']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '13', '80']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '12', '81']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '10', '83']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '6', '87']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '5', '89']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '5', '91']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '5', '96']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '6', '99']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '7', '101']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '9', '103']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '10', '106']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '11', '107']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '16', '112']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '19', '114']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '20', '115']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '23', '116']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '26', '117']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '29', '119']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '36', '120']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '40', '119']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '43', '119']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '48', '119']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '51', '118']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '54', '117']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '58', '116']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '61', '114']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '64', '111']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '71', '105']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '73', '102']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '75', '98']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '77', '94']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '79', '91']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:26', '2017']
# Line:  ['pos:', '81', '87']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '82', '82']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '82', '79']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '82', '76']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '81', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '80', '69']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '79', '68']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '78', '65']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '76', '64']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '74', '63']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '71', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '69', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '65', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '63', '63']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '60', '64']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '58', '66']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '52', '70']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '49', '72']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '47', '74']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '42', '77']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '41', '78']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '38', '79']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '37', '80']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '37', '80']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '35', '80']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '33', '80']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '32', '80']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '32', '80']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '31', '79']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '30', '78']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '29', '77']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '28', '75']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '27', '74']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '27', '74']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '27', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '28', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '28', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '28', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '28', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '28', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '29', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '29', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '29', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '29', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '30', '71']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '30', '70']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '12:08:27', '2017']
# Line:  ['pos:', '30', '70']
# Line:  ['light5', 'OFF', 'Fri', 'Mar', '31', '12:37:56', '2017']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '71', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '72', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '72', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '72', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '72', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '72', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '73', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '73', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '74', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '75', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '76', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '76', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '77', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '77', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:11', '2017']
# Line:  ['pos:', '77', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '78', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '78', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '79', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '80', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '80', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '80', '62']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '81', '61']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '81', '61']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '82', '61']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '82', '61']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '82', '61']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '82', '61']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '83', '60']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '83', '60']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '83', '60']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '84', '60']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '84', '59']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '84', '59']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '85', '59']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '85', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '85', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '85', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '86', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '86', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '86', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '86', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '87', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '87', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '87', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '87', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '87', '58']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '88', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '88', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '88', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '88', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '89', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '89', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '89', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '89', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '90', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '91', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '91', '57']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '92', '56']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '92', '56']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '93', '56']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '93', '56']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '93', '56']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '94', '56']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '95', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:12', '2017']
# Line:  ['pos:', '96', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '97', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '97', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '97', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '98', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '99', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '99', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '99', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '100', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '100', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '101', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '101', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '102', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '102', '55']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '103', '54']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '103', '54']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '103', '54']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '103', '54']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '103', '54']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '104', '54']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '105', '53']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '106', '53']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '107', '53']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '108', '52']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '108', '52']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '109', '52']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '110', '52']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '111', '52']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '112', '51']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '113', '51']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '114', '51']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '115', '51']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '115', '51']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '116', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '118', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '120', '49']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '122', '49']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '123', '49']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '125', '48']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '127', '48']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '129', '47']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '131', '47']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '133', '46']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '134', '46']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '137', '46']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '137', '45']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '138', '45']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '139', '45']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '140', '45']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '141', '45']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:13', '2017']
# Line:  ['pos:', '142', '45']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '143', '45']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '143', '44']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '144', '44']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '145', '44']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '145', '44']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '145', '44']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '146', '44']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '147', '44']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '148', '44']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '149', '44']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '150', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '151', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '152', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '153', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '154', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '155', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '155', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '156', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '157', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '157', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '158', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '158', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '158', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '159', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '160', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '160', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '160', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '160', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '161', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '161', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '161', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '162', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '162', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '163', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '163', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '164', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '164', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '164', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '164', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '165', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:14', '2017']
# Line:  ['pos:', '165', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '165', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '165', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '165', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '165', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '165', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '165', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '165', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '165', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '166', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '166', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '166', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '167', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '167', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '167', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '168', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '168', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '168', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '168', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '168', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '168', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:15', '2017']
# Line:  ['pos:', '168', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '169', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '169', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '169', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '169', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '169', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '169', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '169', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '169', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '170', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '170', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '170', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '170', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '170', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '170', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '170', '40']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '171', '40']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '171', '40']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '171', '40']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '171', '40']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '171', '40']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '171', '40']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '172', '40']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '172', '40']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '172', '40']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '173', '40']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '173', '39']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '173', '39']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '173', '39']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '173', '39']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '173', '39']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '174', '39']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '174', '39']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '174', '39']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '175', '39']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '175', '38']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '175', '38']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '176', '38']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '176', '38']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '177', '37']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '177', '37']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '177', '37']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '178', '37']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '178', '37']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '179', '36']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '180', '36']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '180', '36']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '181', '36']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '181', '35']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:16', '2017']
# Line:  ['pos:', '182', '35']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '183', '35']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '184', '35']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '184', '34']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '185', '34']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '185', '34']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '186', '34']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '186', '34']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '186', '34']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '187', '34']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '188', '34']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '189', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '190', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '191', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '191', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '192', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '192', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '192', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '193', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '194', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '195', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '195', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '196', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '196', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '196', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '198', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '199', '33']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '200', '32']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '201', '32']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '202', '32']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '203', '32']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '204', '32']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '205', '32']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '205', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '206', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '207', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '207', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '207', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '209', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '209', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:17', '2017']
# Line:  ['pos:', '209', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '209', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '209', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '209', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '209', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '209', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:18', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:19', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:19', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:19', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '13:26:19', '2017']
# Line:  ['pos:', '208', '31']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '197', '34']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '196', '34']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '196', '35']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '195', '35']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '195', '35']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '194', '35']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '193', '35']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '190', '35']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '185', '36']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '182', '37']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '180', '37']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '178', '38']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '175', '38']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '171', '39']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '165', '41']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '161', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '158', '42']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '155', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '152', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '149', '43']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '146', '44']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '144', '44']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '142', '45']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '139', '45']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '138', '46']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '136', '46']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '135', '46']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '133', '46']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '130', '47']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '126', '47']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '124', '47']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '122', '47']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '120', '48']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:15', '2017']
# Line:  ['pos:', '118', '48']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '116', '48']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '114', '48']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '112', '49']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '111', '49']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '109', '49']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '108', '49']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '106', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '104', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '102', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '101', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '98', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '97', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '96', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '95', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '94', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '94', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '94', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '94', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '94', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '94', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '96', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '97', '50']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '99', '49']
# Line:  ['positionChanged', 'Fri', 'Mar', '31', '14:03:16', '2017']
# Line:  ['pos:', '102', '49']
# ...
# Line:  ['intensity:', '224', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:43', '2017']
# Line:  ['intensity:', '221', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:43', '2017']
# Line:  ['intensity:', '219', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:43', '2017']
# Line:  ['intensity:', '216', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:43', '2017']
# Line:  ['intensity:', '214', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:43', '2017']
# Line:  ['intensity:', '211', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:44', '2017']
# Line:  ['intensity:', '209', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:44', '2017']
# Line:  ['intensity:', '206', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:44', '2017']
# Line:  ['intensity:', '204', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:44', '2017']
# Line:  ['intensity:', '201', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:44', '2017']
# Line:  ['intensity:', '198', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:44', '2017']
# Line:  ['intensity:', '196', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:44', '2017']
# Line:  ['intensity:', '193', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:44', '2017']
# Line:  ['intensity:', '191', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:45', '2017']
# Line:  ['intensity:', '188', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:45', '2017']
# Line:  ['intensity:', '186', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:45', '2017']
# Line:  ['intensity:', '183', '48692']
# Line:  ['intensityChanged', 'Thu', 'Apr', '6', '17:30:45', '2017']
# Line:  ['intensity:', '181', '48692']
# Line:  ['light6', 'OFF', 'Thu', 'Apr', '6', '17:30:59', '2017']
# Line:  ['light6', 'ON', 'Thu', 'Apr', '6', '17:31:01', '2017']
# Line:  ['light6', 'OFF', 'Thu', 'Apr', '6', '17:31:09', '2017']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:09', '2017']
# Line:  ['pos:', '-52', '-31']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:09', '2017']
# Line:  ['pos:', '-52', '-31']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:10', '2017']
# Line:  ['pos:', '-52', '-31']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:11', '2017']
# Line:  ['pos:', '-52', '-32']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:12', '2017']
# Line:  ['pos:', '-51', '-31']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:12', '2017']
# Line:  ['pos:', '-52', '-31']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:12', '2017']
# Line:  ['pos:', '-52', '-31']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:12', '2017']
# Line:  ['pos:', '-52', '-31']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:12', '2017']
# Line:  ['pos:', '-52', '-31']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:12', '2017']
# Line:  ['pos:', '-51', '-30']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:12', '2017']
# Line:  ['pos:', '-49', '-30']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:12', '2017']
# Line:  ['pos:', '-49', '-30']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:13', '2017']
# Line:  ['pos:', '-49', '-30']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:13', '2017']
# Line:  ['pos:', '-50', '-30']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:13', '2017']
# Line:  ['pos:', '-50', '-30']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:13', '2017']
# Line:  ['pos:', '-50', '-30']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:14', '2017']
# Line:  ['pos:', '-50', '-30']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:14', '2017']
# Line:  ['pos:', '-50', '-29']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:14', '2017']
# Line:  ['pos:', '-51', '-29']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:14', '2017']
# Line:  ['pos:', '-51', '-29']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:14', '2017']
# Line:  ['pos:', '-52', '-30']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:25:14', '2017']
# Line:  ['pos:', '-52', '-31']
# Line:  []
# Line:  ['NewSESSION', 'Fri', 'Apr', '7', '15:26:03', '2017']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:03', '2017']
# Line:  ['pos:', '23', '107']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:03', '2017']
# Line:  ['pos:', '35', '109']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:03', '2017']
# Line:  ['pos:', '86', '92']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:03', '2017']
# Line:  ['pos:', '117', '61']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:03', '2017']
# Line:  ['pos:', '100', '46']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:03', '2017']
# Line:  ['pos:', '67', '59']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:04', '2017']
# Line:  ['pos:', '43', '80']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:04', '2017']
# Line:  ['pos:', '26', '96']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:04', '2017']
# Line:  ['pos:', '18', '102']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:04', '2017']
# Line:  ['pos:', '19', '102']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:04', '2017']
# Line:  ['pos:', '34', '100']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:04', '2017']
# Line:  ['pos:', '48', '96']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:04', '2017']
# Line:  ['pos:', '50', '91']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:04', '2017']
# Line:  ['pos:', '50', '91']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:05', '2017']
# Line:  ['pos:', '49', '91']
# Line:  ['light5', 'ON', 'Fri', 'Apr', '7', '15:26:05', '2017']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:08', '2017']
# Line:  ['pos:', '48', '81']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:08', '2017']
# Line:  ['pos:', '53', '86']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:08', '2017']
# Line:  ['pos:', '55', '87']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:08', '2017']
# Line:  ['pos:', '76', '95']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:08', '2017']
# Line:  ['pos:', '95', '91']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:09', '2017']
# Line:  ['pos:', '99', '86']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:09', '2017']
# Line:  ['pos:', '88', '83']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:09', '2017']
# Line:  ['pos:', '66', '86']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:09', '2017']
# Line:  ['pos:', '65', '87']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:09', '2017']
# Line:  ['pos:', '48', '91']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:09', '2017']
# Line:  ['pos:', '41', '92']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:26:09', '2017']
# Line:  ['pos:', '41', '92']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:11', '2017']
# Line:  ['intensity:', '20', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:11', '2017']
# Line:  ['intensity:', '22', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:11', '2017']
# Line:  ['intensity:', '48', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:11', '2017']
# Line:  ['intensity:', '63', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:11', '2017']
# Line:  ['intensity:', '84', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:11', '2017']
# Line:  ['intensity:', '96', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:11', '2017']
# Line:  ['intensity:', '104', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:11', '2017']
# Line:  ['intensity:', '109', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:11', '2017']
# Line:  ['intensity:', '122', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:12', '2017']
# Line:  ['intensity:', '130', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:12', '2017']
# Line:  ['intensity:', '147', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:12', '2017']
# Line:  ['intensity:', '153', '48692']
# Line:  ['intensityChanged', 'Fri', 'Apr', '7', '15:26:12', '2017']
# Line:  ['intensity:', '155', '48692']
# Line:  ['light5', 'OFF', 'Fri', 'Apr', '7', '15:26:14', '2017']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '114', '28']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '114', '31']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '113', '32']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '112', '33']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '110', '33']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '109', '35']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '106', '37']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '99', '41']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '95', '43']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '90', '44']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '85', '46']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '84', '47']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '79', '48']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '65', '52']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '64', '52']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '62', '52']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '60', '53']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '42', '58']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:33', '2017']
# Line:  ['pos:', '23', '74']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:34', '2017']
# Line:  ['pos:', '21', '77']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:34', '2017']
# Line:  ['pos:', '21', '77']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:35', '2017']
# Line:  ['pos:', '25', '85']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:35', '2017']
# Line:  ['pos:', '25', '85']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:35', '2017']
# Line:  ['pos:', '35', '97']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:35', '2017']
# Line:  ['pos:', '49', '108']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:35', '2017']
# Line:  ['pos:', '50', '109']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:35', '2017']
# Line:  ['pos:', '71', '104']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:36', '2017']
# Line:  ['pos:', '85', '78']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:36', '2017']
# Line:  ['pos:', '74', '66']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:36', '2017']
# Line:  ['pos:', '54', '76']
# Line:  ['positionChanged', 'Fri', 'Apr', '7', '15:40:36', '2017']
# Line:  ['pos:', '51', '77']
# Line:  ['light5', 'ON', 'Fri', 'Apr', '7', '15:40:57', '2017']
# Line:  ['light5', 'OFF', 'Fri', 'Apr', '7', '15:41:26', '2017']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '51', '78']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '51', '78']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '51', '78']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '51', '78']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '50', '79']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '50', '79']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '49', '79']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '49', '79']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '47', '80']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '46', '81']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '45', '82']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '43', '83']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '42', '84']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:57', '2017']
# Line:  ['pos:', '42', '85']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '40', '86']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '39', '87']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '39', '88']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '37', '88']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '37', '89']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '36', '89']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '36', '89']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '36', '89']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '35', '90']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '34', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '33', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '32', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '32', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '31', '92']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '31', '92']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '29', '92']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '28', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '28', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '26', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '26', '90']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '90']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '90']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '90']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '90']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '90']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '90']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:58', '2017']
# Line:  ['pos:', '25', '91']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:59', '2017']
# Line:  ['pos:', '25', '92']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:59', '2017']
# Line:  ['pos:', '25', '92']
# Line:  ['positionChanged', 'Tue', 'Apr', '18', '09:47:59', '2017']
# Line:  ['pos:', '25', '92']
# Line:  []

# %%
# look for how many times a light was turned on / off (tablet)
Light1ON = 0
Light1OFF = 0
Light2ON = 0
Light2OFF = 0
Light3ON = 0
Light3OFF = 0
Light4ON = 0
Light4OFF = 0
Light5ON = 0
Light5OFF = 0
Light6ON = 0
Light6OFF = 0
Light7ON = 0
Light7OFF = 0

if fileTablet.find('tablet') !=-1:
    #Loop through all the lines in the file
    for num3 in range(len(fileListTablet)):
        strline = fileListTablet[num3]
        #print('num:', num2)
        if len(strline) == 0:
            # do nothing
            x = 1
        #light1
        elif 'light1' == strline[0] and 'ON' == strline[1]:
            Light1ON = Light1ON + 1
            print('1:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light1' == strline[0] and 'OFF' == strline[1]:
            Light1OFF = Light1OFF + 1
            print('1:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light2
        elif 'light2' == strline[0] and 'ON' == strline[1]:
            Light2ON = Light2ON + 1
            print('2:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light2' == strline[0] and 'OFF' == strline[1]:
            Light2OFF = Light2OFF + 1
            print('2:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light3
        elif 'light3' == strline[0] and 'ON' == strline[1]:
            Light3ON = Light3ON + 1
            print('3:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light3' == strline[0] and 'OFF' == strline[1]:
            Light3OFF = Light3OFF + 1
            print('3:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light4
        elif 'light4' == strline[0] and 'ON' == strline[1]:
            Light4ON = Light4ON + 1
            print('4:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light4' == strline[0] and 'OFF' == strline[1]:
            Light4OFF = Light4OFF + 1
            print('4:', strline[0], 'was turned OFF', strline[2], 'at', strline[5])
        
        #light5
        elif 'light5' == strline[0] and 'ON' == strline[1]:
            Light5ON = Light5ON + 1
            print('5:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light5' == strline[0] and 'OFF' == strline[1]:
            Light5OFF = Light5OFF + 1
            print('5:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light6
        elif 'light6' == strline[0] and 'ON' == strline[1]:
            Light6ON = Light6ON + 1
            print('6:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light6' == strline[0] and 'OFF' == strline[1]:
            Light6OFF = Light6OFF + 1
            print('6:', strline[0], 'was turned OFF ', strline[2], 'at', strline[5])
        
        #light7
        elif 'light7' == strline[0] and 'ON' == strline[1]:
            Light7ON = Light7ON + 1
            print('7:', strline[0], 'was turned ON ', strline[2], 'at', strline[5])

        elif 'light7' == strline[0] and 'OFF' == strline[1]:
            Light7OFF = Light7OFF + 1
            print('7:', strline[0], 'was turned OFF', strline[2], 'at', strline[5])
       
print('Light1 turned ON: ', Light1ON)
print('Light1 turned OFF: ', Light1OFF)
print('Light2 turned ON: ', Light2ON)
print('Light2 turned OFF: ', Light2OFF)
print('Light3 turned ON: ', Light3ON)
print('Light3 turned OFF: ', Light3OFF)
print('Light4 turned ON: ', Light4ON)
print('Light4 turned OFF: ', Light4OFF)
print('Light5 turned ON: ', Light5ON)
print('Light5 turned OFF: ', Light5OFF)
print('Light6 turned ON: ', Light6ON)
print('Light6 turned OFF: ', Light6OFF)
print('Light7 turned ON: ', Light7ON)
print('Light7 turned OFF: ', Light7OFF)
# Out:
# 5: light5 was turned ON  Fri at 12:03:53
# 3: light3 was turned ON  Fri at 12:03:55
# 3: light3 was turned OFF  Fri at 12:03:56
# 4: light4 was turned ON  Fri at 12:03:56
# 7: light7 was turned ON  Fri at 12:03:57
# 6: light6 was turned ON  Fri at 12:03:57
# 1: light1 was turned ON  Fri at 12:03:58
# 2: light2 was turned ON  Fri at 12:03:58
# 3: light3 was turned ON  Fri at 12:03:59
# 5: light5 was turned OFF  Fri at 12:03:59
# 2: light2 was turned OFF  Fri at 12:04:00
# 3: light3 was turned OFF  Fri at 12:04:00
# 4: light4 was turned OFF Fri at 12:04:01
# 7: light7 was turned OFF Fri at 12:04:01
# 6: light6 was turned OFF  Fri at 12:04:01
# 1: light1 was turned OFF  Fri at 12:04:04
# 5: light5 was turned ON  Fri at 12:06:32
# 5: light5 was turned OFF  Fri at 12:37:56
# 6: light6 was turned ON  Tue at 15:51:55
# 6: light6 was turned OFF  Tue at 15:51:56
# 5: light5 was turned ON  Tue at 15:51:58
# 4: light4 was turned ON  Wed at 11:21:05
# 7: light7 was turned ON  Wed at 11:21:06
# 6: light6 was turned ON  Wed at 11:21:07
# 1: light1 was turned ON  Wed at 11:21:07
# 2: light2 was turned ON  Wed at 11:21:08
# 3: light3 was turned ON  Wed at 11:21:09
# 2: light2 was turned OFF  Wed at 11:21:10
# 3: light3 was turned OFF  Wed at 11:21:10
# 4: light4 was turned OFF Wed at 11:21:11
# 7: light7 was turned OFF Wed at 11:21:12
# 6: light6 was turned OFF  Wed at 11:21:12
# 1: light1 was turned OFF  Wed at 11:21:13
# 5: light5 was turned OFF  Wed at 11:21:13
# 5: light5 was turned ON  Wed at 11:21:29
# 4: light4 was turned ON  Wed at 11:21:30
# 7: light7 was turned ON  Wed at 11:21:31
# 6: light6 was turned ON  Wed at 11:21:32
# 1: light1 was turned ON  Wed at 11:21:33
# 2: light2 was turned ON  Wed at 11:21:34
# 3: light3 was turned ON  Wed at 11:21:35
# 3: light3 was turned OFF  Wed at 11:21:39
# 2: light2 was turned OFF  Wed at 11:21:40
# 1: light1 was turned OFF  Wed at 11:21:40
# 6: light6 was turned OFF  Wed at 11:21:41
# 7: light7 was turned OFF Wed at 11:21:42
# 4: light4 was turned OFF Wed at 11:21:43
# 5: light5 was turned OFF  Wed at 11:21:44
# 5: light5 was turned ON  Wed at 11:22:13
# 4: light4 was turned ON  Wed at 11:22:16
# 7: light7 was turned ON  Wed at 11:22:17
# 6: light6 was turned ON  Wed at 11:22:18
# 1: light1 was turned ON  Wed at 11:22:20
# 2: light2 was turned ON  Wed at 11:22:21
# 3: light3 was turned ON  Wed at 11:22:22
# 3: light3 was turned OFF  Wed at 11:22:26
# 2: light2 was turned OFF  Wed at 11:22:27
# 1: light1 was turned OFF  Wed at 11:22:28
# 6: light6 was turned OFF  Wed at 11:22:29
# 7: light7 was turned OFF Wed at 11:22:30
# 4: light4 was turned OFF Wed at 11:22:31
# 5: light5 was turned OFF  Wed at 11:22:32
# 5: light5 was turned ON  Wed at 11:40:50
# 2: light2 was turned ON  Thu at 17:26:50
# 5: light5 was turned OFF  Thu at 17:26:51
# 5: light5 was turned ON  Thu at 17:26:52
# 3: light3 was turned ON  Thu at 17:26:53
# 4: light4 was turned ON  Thu at 17:26:53
# 7: light7 was turned ON  Thu at 17:26:54
# 6: light6 was turned ON  Thu at 17:26:54
# 1: light1 was turned ON  Thu at 17:26:55
# 5: light5 was turned OFF  Thu at 17:27:13
# 4: light4 was turned OFF Thu at 17:27:14
# 7: light7 was turned OFF Thu at 17:27:14
# 6: light6 was turned OFF  Thu at 17:27:15
# 1: light1 was turned OFF  Thu at 17:27:15
# 2: light2 was turned OFF  Thu at 17:27:16
# 3: light3 was turned OFF  Thu at 17:27:16
# 3: light3 was turned ON  Thu at 17:28:11
# 3: light3 was turned OFF  Thu at 17:28:14
# 5: light5 was turned ON  Thu at 17:28:39
# 2: light2 was turned ON  Thu at 17:28:40
# 3: light3 was turned ON  Thu at 17:28:41
# 4: light4 was turned ON  Thu at 17:28:42
# 7: light7 was turned ON  Thu at 17:28:42
# 6: light6 was turned ON  Thu at 17:28:43
# 1: light1 was turned ON  Thu at 17:28:43
# 1: light1 was turned OFF  Thu at 17:28:45
# 6: light6 was turned OFF  Thu at 17:28:46
# 7: light7 was turned OFF Thu at 17:28:46
# 3: light3 was turned OFF  Thu at 17:28:47
# 4: light4 was turned OFF Thu at 17:28:48
# 2: light2 was turned OFF  Thu at 17:28:48
# 5: light5 was turned OFF  Thu at 17:29:06
# 1: light1 was turned ON  Thu at 17:29:22
# 2: light2 was turned ON  Thu at 17:29:23
# 3: light3 was turned ON  Thu at 17:29:24
# 4: light4 was turned ON  Thu at 17:29:25
# 7: light7 was turned ON  Thu at 17:29:25
# 6: light6 was turned ON  Thu at 17:29:26
# 5: light5 was turned ON  Thu at 17:29:26
# 2: light2 was turned OFF  Thu at 17:29:29
# 1: light1 was turned OFF  Thu at 17:29:29
# 5: light5 was turned OFF  Thu at 17:29:31
# 3: light3 was turned OFF  Thu at 17:29:31
# 3: light3 was turned ON  Thu at 17:29:31
# 3: light3 was turned OFF  Thu at 17:29:32
# 4: light4 was turned OFF Thu at 17:29:33
# 7: light7 was turned OFF Thu at 17:29:35
# 6: light6 was turned OFF  Thu at 17:30:59
# 6: light6 was turned ON  Thu at 17:31:01
# 6: light6 was turned OFF  Thu at 17:31:09
# 5: light5 was turned ON  Fri at 15:26:05
# 5: light5 was turned OFF  Fri at 15:26:14
# 5: light5 was turned ON  Fri at 15:40:57
# 5: light5 was turned OFF  Fri at 15:41:26
# Light1 turned ON:  7
# Light1 turned OFF:  7
# Light2 turned ON:  7
# Light2 turned OFF:  7
# Light3 turned ON:  10
# Light3 turned OFF:  10
# Light4 turned ON:  7
# Light4 turned OFF:  7
# Light5 turned ON:  11
# Light5 turned OFF:  11
# Light6 turned ON:  9
# Light6 turned OFF:  9
# Light7 turned ON:  7
# Light7 turned OFF:  7

# %%
# look for how many times the light intensity was changed(tablet)
LightIntensity = 0
lastTime = 0
lastDay= 0

if fileTablet.find('tablet') !=-1:
    for num4, strline in enumerate(fileListTablet):
        if len(strline) == 0:
            # do nothing
            x = 1
        # ['intensityChanged', 'Fri', 'Mar', '31', '12:03:47', '2017']
        if 'intensityChanged' in strline:
            t = strline[4]
            (h, m, s) = t.split(':')
            result = int(h) * 3600 + int(m) * 60 + int(s)
            #print('time in seconds: ', result)
            if lastTime == 0:
                lastDay = strline[1]
                lastTime = result
                print('light intensity changed for first time in file: ', strline[4], ' day: ', lastDay)
            elif (result - lastTime) < 60 and (result - lastTime) > -1:
                lastDay = strline[1]
                lastTime = result
            else: # count at end of movement
                LightIntensity = LightIntensity + 1
                print('light intensity ++: ', lastTime, ' day: ', lastDay)
                lastDay = strline[3]
                lastTime = result

print('Light intensity: ', LightIntensity+1) # will not have counted last one
# Out:
# light intensity changed for first time in file:  12:03:45  day:  Fri
# light intensity ++:  43431  day:  Fri
# light intensity ++:  62831  day:  Thu
# light intensity ++:  63045  day:  Thu
# Light intensity:  4

# %%
# look for how many times the lights were moved (tablet)
LightMoved = 0
lastResult = 0
lastDay = 0
lastTime = 0

listOfMovementsTabletX = []
listOfMovementsTabletY = []
listOfMovementsTabletT = []
tempListX = []
tempListY = []
tempListT = []

if fileTablet.find('tablet') !=-1:
    for num5, strline in enumerate(fileListTablet):
        if len(strline) == 0:
            # do nothing
            x = 1
        # ['positionChanged', 'Fri', 'Mar', '31', '12:03:40', '2017']
        elif 'positionChanged' in strline:
            #print('position changed: ', strline[1], ' time: ', strline[4], ' dif: ', (result-lastTime) )
            t = strline[4]
            (h, m, s) = t.split(':')
            result = int(h) * 3600 + int(m) * 60 + int(s)
            #print('time in seconds: ', result)
            if lastTime == 0:
                lastDay = strline[1]
                lastResult = result
                lastTime = strline[4]
                print('light moved for first time in file: ', lastTime)
            elif (result - lastResult) < 20 and (result - lastResult) > -1:
                lastDay = strline[1]
                lastResult = result
                lastTime = strline[4]
                #print('still in same movement')
            else: 
                listOfMovementsTabletX.append(tempListX)
                listOfMovementsTabletY.append(tempListY)
                listOfMovementsTabletT.append(tempListT)
                # clear lists
                tempListX = []
                tempListY = []
                tempListT = []
                # count at end of movement
                LightMoved = LightMoved + 1
                print('light moved ++, day: ', lastDay, ' time: ',  lastTime)
                lastDay = strline[1]
                lastResult = result
                lastTime = strline[4]
            tempListT.append(result)
        if 'pos:' in strline:
            tempListX.append(strline[1])
            tempListY.append(strline[2])

listOfMovementsTabletX.append(tempListX)
listOfMovementsTabletY.append(tempListY)
listOfMovementsTabletT.append(tempListT)

print('light moved ++, day: ', lastDay, ' time: ',  lastTime)
print('Lights moved: ', LightMoved+1) # will not have counted last one
print('Length of movement list X: ', len(listOfMovementsTabletX))
print('Length of movement list T: ', len(listOfMovementsTabletT))
# Out:
# light moved for first time in file:  12:03:40
# light moved ++, day:  Fri  time:  12:03:41
# light moved ++, day:  Fri  time:  12:04:11
# light moved ++, day:  Fri  time:  12:08:27
# light moved ++, day:  Fri  time:  13:26:19
# light moved ++, day:  Fri  time:  14:03:24
# light moved ++, day:  Tue  time:  11:05:09
# light moved ++, day:  Tue  time:  15:52:03
# light moved ++, day:  Wed  time:  11:31:02
# light moved ++, day:  Thu  time:  17:15:42
# light moved ++, day:  Thu  time:  17:26:11
# light moved ++, day:  Thu  time:  17:27:04
# light moved ++, day:  Thu  time:  17:29:01
# light moved ++, day:  Thu  time:  17:29:50
# light moved ++, day:  Fri  time:  15:25:14
# light moved ++, day:  Fri  time:  15:26:09
# light moved ++, day:  Fri  time:  15:40:36
# light moved ++, day:  Tue  time:  09:47:59
# Lights moved:  17
# Length of movement list X:  17
# Length of movement list T:  17

# %%
print('Length of movement list X: ', len(listOfMovementsTabletX))
print('Length of movement list T: ', len(listOfMovementsTabletT))

if fileTablet.find('tablet') !=-1:
    for i, movementX in enumerate(listOfMovementsTabletX):
        print('i: ', i)
        print('Length X: ', len(listOfMovementsTabletX[i]))
        print('Length Y: ', len(listOfMovementsTabletY[i]))
        print('Length T: ', len(listOfMovementsTabletT[i]))
        plt.scatter(listOfMovementsTabletX[i], listOfMovementsTabletY[i], c=listOfMovementsTabletT[i], s=50, cmap='winter')
        axes = plt.gca()
        axes.set_xlim([250,-100])
        axes.set_ylim([-50,200])
        plt.show()
# Out:
# Length of movement list X:  17
# Length of movement list T:  17
# i:  0
# Length X:  16
# Length Y:  16
# Length T:  16
# i:  1
# Length X:  5
# Length Y:  5
# Length T:  5
# i:  2
# Length X:  99
# Length Y:  99
# Length T:  99
# i:  3
# Length X:  285
# Length Y:  285
# Length T:  285
# i:  4
# Length X:  377
# Length Y:  377
# Length T:  377
# i:  5
# Length X:  3
# Length Y:  3
# Length T:  3
# i:  6
# Length X:  177
# Length Y:  177
# Length T:  177
# i:  7
# Length X:  650
# Length Y:  650
# Length T:  650
# i:  8
# Length X:  256
# Length Y:  256
# Length T:  256
# i:  9
# Length X:  2
# Length Y:  2
# Length T:  2
# i:  10
# Length X:  282
# Length Y:  282
# Length T:  282
# i:  11
# Length X:  423
# Length Y:  423
# Length T:  423
# i:  12
# Length X:  410
# Length Y:  410
# Length T:  410
# i:  13
# Length X:  22
# Length Y:  22
# Length T:  22
# i:  14
# Length X:  27
# Length Y:  27
# Length T:  27
# i:  15
# Length X:  31
# Length Y:  31
# Length T:  31
# i:  16
# Length X:  49
# Length Y:  49
# Length T:  49
